# %%
import tensorflow as tf
from tensorflow.keras import models,layers
import matplotlib.pyplot as plt
from IPython.display import HTML

from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
IMAGE_SIZE = 600
IMAGE_SIZE1= 800
BATCH_SIZE = 32
EPOCHS =5
CHANNELS = 3

train_data_gen = ImageDataGenerator(rescale=1./255,
                  rotation_range=10,
                  horizontal_flip=True)

train_generator = train_data_gen.flow_from_directory(
'dataset/train',
target_size=(IMAGE_SIZE,IMAGE_SIZE1),
batch_size=32,
class_mode="sparse",

)
# Out:
# Found 835 images belonging to 6 classes.

# %%
# for image_batch,label_batch in train_generator:
#     print(image_batch)
#     break

# %%
train_generator.class_indices
# Out:
# {'180': 0, '240': 1, '320': 2, '400': 3, 'blank': 4, 'reject': 5}

# %%
class_names = list(train_generator.class_indices.keys())
class_names
# Out:
# ['180', '240', '320', '400', 'blank', 'reject']

# %%
dir(train_generator.classes.shape)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']
